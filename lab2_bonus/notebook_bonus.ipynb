# %% [markdown]
# # Week06 Bonus Notebook
# Debye 热容积分与方法对比

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.advanced_model import cv_scan

# %%
# TODO D3: 画出 C_V(T) 曲线，并验证低温 T^3 趋势与高温平台趋势
pass
