# %% [markdown]
# # Week06 Core Notebook
# 任务C：误差验证与可视化

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.physics_model import f_diff, df_diff_true
from src.solver import forward_diff, central_diff

# %%
# TODO C1: 画误差-步长双对数图，并解释最优步长
pass
